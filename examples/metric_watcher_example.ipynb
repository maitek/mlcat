# %%
from mlcat.logging import MetricWatcher
from IPython.display import clear_output
import matplotlib.pyplot as plt

with MetricWatcher(watch_vars = ["a", "b"]) as mw:
    for a in range(10):
        b = a**2
        mw.update(scope=locals()) # update
        clear_output(wait=True) # update plot by clearing notebook 
        mw.plot_metrics(["b"])
        mw.print_metrics()
# Out:
# | a: 9 | b: 81 |
